# %%
#Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages (2.8.6)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.1.1; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\gagans\appdata\local\programs\python\python38-32\python.exe -m pip install --upgrade pip' command.

# %%
# Use Pandas to read data
data = "data/concat_decades_data_w_decade.csv"
data0 = pd.read_csv(data)
data0.head()
# Out:
#    Number                                              title  \
# 0       1                       Put Your Head On My Shoulder
# 1       2  Whatever Will Be Will Be (Que Sera Sera) (with...
# 2       3                           Everybody Loves Somebody
# 3       4        Take Good Care Of My Baby - 1990 Remastered
# 4       5                                 A Teenager In Love
#
#                 artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0            Paul Anka  adult standards  2000  116    34    55  -9    10   47
# 1            Doris Day  adult standards  1948  177    34    42 -11    72   78
# 2          Dean Martin  adult standards  2013   81    49    26  -9    34   40
# 3            Bobby Vee  adult standards  2011   82    43    49 -12    12   66
# 4  Dion & The Belmonts  adult standards  1959   79    38    56  -9    13   62
#
#    dur  acous  spch  pop  decade
# 0  155     75     3   72    1950
# 1  123     86     4   62    1950
# 2  162     81     4   61    1950
# 3  151     70     6   60    1950
# 4  158     67     3   60    1950

# %%
data1=data0.drop(columns={"Number","bpm","live","dur","acous","spch","dur","acous","spch","dB"})
data1.head()
# Out:
#                                                title               artist  \
# 0                       Put Your Head On My Shoulder            Paul Anka
# 1  Whatever Will Be Will Be (Que Sera Sera) (with...            Doris Day
# 2                           Everybody Loves Somebody          Dean Martin
# 3        Take Good Care Of My Baby - 1990 Remastered            Bobby Vee
# 4                                 A Teenager In Love  Dion & The Belmonts
#
#          top genre  year  nrgy  dnce  val  pop  decade
# 0  adult standards  2000    34    55   47   72    1950
# 1  adult standards  1948    34    42   78   62    1950
# 2  adult standards  2013    49    26   40   61    1950
# 3  adult standards  2011    43    49   66   60    1950
# 4  adult standards  1959    38    56   62   60    1950

# %%
data5=data1.rename(columns={"top genre":"genres","dnce":"danceability","nrgy":"energy","val":"valence","pop":"popularity"})
data5.head()
# Out:
#                                                title               artist  \
# 0                       Put Your Head On My Shoulder            Paul Anka
# 1  Whatever Will Be Will Be (Que Sera Sera) (with...            Doris Day
# 2                           Everybody Loves Somebody          Dean Martin
# 3        Take Good Care Of My Baby - 1990 Remastered            Bobby Vee
# 4                                 A Teenager In Love  Dion & The Belmonts
#
#             genres  year  energy  danceability  valence  popularity  decade
# 0  adult standards  2000      34            55       47          72    1950
# 1  adult standards  1948      34            42       78          62    1950
# 2  adult standards  2013      49            26       40          61    1950
# 3  adult standards  2011      43            49       66          60    1950
# 4  adult standards  1959      38            56       62          60    1950

# %%
# Use Pandas to read data
data2 = "data/data_by_genres.csv"
data3 = pd.read_csv(data2)
data3.head()
# Out:
#            genres  acousticness  danceability   duration_ms    energy  \
# 0           432hz      0.494780      0.299333  1.048887e+06  0.450678
# 1              []      0.679245      0.521473  2.298526e+05  0.401522
# 2      a cappella      0.621532      0.577017  1.936522e+05  0.345694
# 3        abstract      0.359395      0.459500  3.430185e+05  0.487000
# 4  abstract beats      0.353347      0.694400  2.338244e+05  0.613400
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.477762  0.131000 -16.854000     0.076817  120.285667  0.221750
# 1          0.196737  0.221586 -12.679076     0.112267  112.025168  0.515920
# 2          0.003799  0.127087 -12.770211     0.095324  111.813230  0.453186
# 3          0.791400  0.119480 -14.092000     0.043420  124.743200  0.304990
# 4          0.349403  0.102453  -6.699800     0.143453  119.398400  0.634187
#
#    popularity  key  mode
# 0   52.166667    5     1
# 1   21.682005    7     1
# 2   43.351819   11     1
# 3   41.500000    1     1
# 4   58.600000   10     0

# %%
data4=data3.drop(columns={"acousticness","duration_ms","instrumentalness","liveness","loudness","speechiness","tempo","key","mode"})
data4.head()
# Out:
#            genres  danceability    energy   valence  popularity
# 0           432hz      0.299333  0.450678  0.221750   52.166667
# 1              []      0.521473  0.401522  0.515920   21.682005
# 2      a cappella      0.577017  0.345694  0.453186   43.351819
# 3        abstract      0.459500  0.487000  0.304990   41.500000
# 4  abstract beats      0.694400  0.613400  0.634187   58.600000

# %%
#Loading the data
connection_string = "postgres://postgres:gs@localhost/spotify"
conn = create_engine(connection_string)

# %%
data4.to_sql(name="by_genre", con=conn, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-10-65f03a4eac33> in <module>
# ----> 1 data4.to_sql(name="by_genre", con=conn, if_exists="replace", index=False)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2776         from pandas.io import sql
#    2777
# -> 2778         sql.to_sql(
#    2779             self,
#    2780             name,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1390             dtype=dtype,
#    1391         )
# -> 1392         table.create()
#    1393
#    1394         from sqlalchemy import exc
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in create(self)
#     720
#     721     def create(self):
# --> 722         if self.exists():
#     723             if self.if_exists == "fail":
#     724                 raise ValueError(f"Table '{self.name}' already exists.")
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in exists(self)
#     707
#     708     def exists(self):
# --> 709         return self.pd_sql.has_table(self.name, self.schema)
#     710
#     711     def sql_schema(self):
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1427
#    1428     def has_table(self, name, schema=None):
# -> 1429         return self.connectable.run_callable(
#    1430             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1431         )
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     506     def connect(self, *cargs, **cparams):
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#     510     def create_connect_args(self, url):
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
data5.to_sql(name="by_decade", con=conn, if_exists="replace", index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-11-d9d55d6b1f1f> in <module>
# ----> 1 data5.to_sql(name="by_decade", con=conn, if_exists="replace", index=False)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2776         from pandas.io import sql
#    2777
# -> 2778         sql.to_sql(
#    2779             self,
#    2780             name,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     588         )
#     589
# --> 590     pandas_sql.to_sql(
#     591         frame,
#     592         name,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1390             dtype=dtype,
#    1391         )
# -> 1392         table.create()
#    1393
#    1394         from sqlalchemy import exc
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in create(self)
#     720
#     721     def create(self):
# --> 722         if self.exists():
#     723             if self.if_exists == "fail":
#     724                 raise ValueError(f"Table '{self.name}' already exists.")
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in exists(self)
#     707
#     708     def exists(self):
# --> 709         return self.pd_sql.has_table(self.name, self.schema)
#     710
#     711     def sql_schema(self):
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1427
#    1428     def has_table(self, name, schema=None):
# -> 1429         return self.connectable.run_callable(
#    1430             self.connectable.dialect.has_table, name, schema or self.meta.schema
#    1431         )
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in run_callable(self, callable_, *args, **kwargs)
#    2209
#    2210         """
# -> 2211         with self._contextual_connect() as conn:
#    2212             return conn.run_callable(callable_, *args, **kwargs)
#    2213
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     506     def connect(self, *cargs, **cparams):
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#     510     def create_connect_args(self, url):
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)

# %%
pd.read_sql("select * from .......",conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     181         try:
# --> 182             raise exception
#     183         finally:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#
# OperationalError: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-12-9ac11f77acab> in <module>
# ----> 1 pd.read_sql("select * from .......",conn)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     508         )
#     509     else:
# --> 510         return pandas_sql.read_query(
#     511             sql,
#     512             index_col=index_col,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1292         args = _convert_params(sql, params)
#    1293
# -> 1294         result = self.execute(*args)
#    1295         columns = result.keys()
#    1296
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1160     def execute(self, *args, **kwargs):
#    1161         """Simple passthrough to SQLAlchemy connectable"""
# -> 1162         return self.connectable.execution_options().execute(*args, **kwargs)
#    1163
#    1164     def read_table(
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2232         """
#    2233
# -> 2234         connection = self._contextual_connect(close_with_result=True)
#    2235         return connection.execute(statement, *multiparams, **params)
#    2236
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _contextual_connect(self, close_with_result, **kwargs)
#    2300         return self._connection_cls(
#    2301             self,
# -> 2302             self._wrap_pool_connect(self.pool.connect, None),
#    2303             close_with_result=close_with_result,
#    2304             **kwargs
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
# -> 2339                 Connection._handle_dbapi_exception_noconnection(
#    2340                     e, dialect, self
#    2341                 )
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1581             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1582         elif should_wrap:
# -> 1583             util.raise_(
#    1584                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1585             )
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2334         dialect = self.dialect
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#    2338             if connection is None:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         """
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#     366         try:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     776     def _checkout(cls, pool, threadconns=None, fairy=None):
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#     780             fairy._pool = pool
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     493     @classmethod
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#     497             dbapi_connection = rec.get_connection()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     138             except:
#     139                 with util.safe_reraise():
# --> 140                     self._dec_overflow()
#     141         else:
#     142             return self._do_get()
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     135         if self._inc_overflow():
#     136             try:
# --> 137                 return self._create_connection()
#     138             except:
#     139                 with util.safe_reraise():
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     307         """Called by subclasses to create a new ConnectionRecord."""
#     308
# --> 309         return _ConnectionRecord(self)
#     310
#     311     def _invalidate(self, connection, exception=None, _checkin=True):
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     438         self.__pool = pool
#     439         if connect:
# --> 440             self.__connect(first_connect_check=True)
#     441         self.finalize_callback = deque()
#     442
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     659         except Exception as e:
#     660             with util.safe_reraise():
# --> 661                 pool.logger.debug("Error on connect(): %s", e)
#     662         else:
#     663             if first_connect_check:
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      66             self._exc_info = None  # remove potential circular references
#      67             if not self.warn_only:
# ---> 68                 compat.raise_(
#      69                     exc_value,
#      70                     with_traceback=exc_tb,
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\pool\base.py in __connect(self, first_connect_check)
#     654         try:
#     655             self.starttime = time.time()
# --> 656             connection = pool._invoke_creator(self)
#     657             pool.logger.debug("Created new connection %r", connection)
#     658             self.connection = connection
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     112                         if connection is not None:
#     113                             return connection
# --> 114                 return dialect.connect(*cargs, **cparams)
#     115
#     116             creator = pop_kwarg("creator", connect)
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     506     def connect(self, *cargs, **cparams):
#     507         # inherits the docstring from interfaces.Dialect.connect
# --> 508         return self.dbapi.connect(*cargs, **cparams)
#     509
#     510     def create_connect_args(self, url):
#
# c:\users\gagans\appdata\local\programs\python\python38-32\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125
#     126     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 127     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     128     if cursor_factory is not None:
#     129         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: http://sqlalche.me/e/13/e3q8)
